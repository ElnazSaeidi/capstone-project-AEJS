# %% [markdown]
# ## Download weather data via API

# %%
# Import the necessary package
import pandas as pd
import numpy as np
import requests 
import json
from matplotlib import pyplot as plt

# %%
#pip install meteostat

# %%
# defining the weather station codes via meteostat

# %%
# Download weather data from different stations in the countries Brasil, France and Canada
# Starting with Brasil

url = "https://meteostat.p.rapidapi.com/stations/daily"

# Set stations
stations = ["83362",
            "82191",
            "83967"
            ]

# Set API key (defined already)
headers = {
	"X-RapidAPI-Key": "38c2ec0004msh8992e15e6b32155p15fd43jsn0376b99a111e",
	"X-RapidAPI-Host": "meteostat.p.rapidapi.com"
}

# Create empty dataframe, will be used to append each location's weather data
weather_df = pd.DataFrame([])



# Loop through all locations
for station in stations:
    # API call start for open weather
    querystring = {"station":station,"start":"2010-01-01","end":"2019-01-01"}

    response = requests.get(url, headers=headers, params=querystring)
    #API call end

    # time.sleep(1) #uncomment if you run into a query limit
    
    # Decode repsonse with json decoder
    weather_temp = response.json()
    
    # Flatten json response
    weather_temp_df = pd.json_normalize(weather_temp, 
                                        sep="_", 
                                        record_path="data",
                                        meta=["station"], 
                                        record_prefix="weather_",
                                        errors='ignore'
                                        )
    weather_temp_df['station']=station
    # concatenate dataframes
    weather_df = pd.concat([weather_df, weather_temp_df], ignore_index=True)

# Print final dataset weather_df
weather_df_brazil=weather_df
weather_df_brazil
# Out:
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_5366/3211821515.py:46: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   weather_df = pd.concat([weather_df, weather_temp_df], ignore_index=True)
#      weather_date  weather_tavg  weather_tmin  weather_tmax weather_prcp  \
# 0      2010-01-01          26.4          22.4          32.0         None
# 1      2010-01-02          24.3          23.8          26.0         None
# 2      2010-01-03          26.8          24.0          32.0         None
# 3      2010-01-04          29.2          23.0          35.0         None
# 4      2010-01-05          30.2          26.0          35.5         None
# ...           ...           ...           ...           ...          ...
# 9859   2018-12-28          28.9           NaN           NaN         None
# 9860   2018-12-29          28.3           NaN           NaN         None
# 9861   2018-12-30          29.1           NaN           NaN         None
# 9862   2018-12-31          27.9           NaN           NaN         None
# 9863   2019-01-01          29.8           NaN           NaN         None
#
#      weather_snow  weather_wdir  weather_wspd weather_wpgt  weather_pres  \
# 0            None           NaN          11.7         None           NaN
# 1            None           NaN          11.9         None           NaN
# 2            None           NaN          13.1         None           NaN
# 3            None           NaN           9.5         None           NaN
# 4            None          12.0          10.3         None           NaN
# ...           ...           ...           ...          ...           ...
# 9859         None           NaN           NaN         None           NaN
# 9860         None           NaN           NaN         None           NaN
# 9861         None           NaN           NaN         None           NaN
# 9862         None           NaN           NaN         None           NaN
# 9863         None           NaN           NaN         None           NaN
#
#      weather_tsun station
# 0            None   83362
# 1            None   83362
# 2            None   83362
# 3            None   83362
# 4            None   83362
# ...           ...     ...
# 9859         None   83967
# 9860         None   83967
# 9861         None   83967
# 9862         None   83967
# 9863         None   83967
#
# [9864 rows x 12 columns]

# %%
# Download weather data from different stations in the countries Brasil, France and Canada
# Canada

url = "https://meteostat.p.rapidapi.com/stations/daily"

# Set stations
stations = ["71863",
            "71508",
            "71877"
            ]

# Set API key (defined already)
headers = {
	"X-RapidAPI-Key": "38c2ec0004msh8992e15e6b32155p15fd43jsn0376b99a111e",
	"X-RapidAPI-Host": "meteostat.p.rapidapi.com"
}

# Create empty dataframe, will be used to append each location's weather data
weather_df = pd.DataFrame([])



# Loop through all locations
for station in stations:
    # API call start for open weather
    querystring = {"station":station,"start":"2010-01-01","end":"2019-01-01"}

    response = requests.get(url, headers=headers, params=querystring)
    #API call end

    # time.sleep(1) #uncomment if you run into a query limit
    
    # Decode repsonse with json decoder
    weather_temp = response.json()
    
    # Flatten json response
    weather_temp_df = pd.json_normalize(weather_temp, 
                                        sep="_", 
                                        record_path="data",
                                        meta=["station"], 
                                        record_prefix="weather_",
                                        errors='ignore'
                                        )
    weather_temp_df['station']=station
    # concatenate dataframes
    weather_df = pd.concat([weather_df, weather_temp_df], ignore_index=True)

# Print final dataset weather_df
weather_df_can=weather_df
weather_df_can
# Out:
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_5366/1924104632.py:46: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   weather_df = pd.concat([weather_df, weather_temp_df], ignore_index=True)
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_5366/1924104632.py:46: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   weather_df = pd.concat([weather_df, weather_temp_df], ignore_index=True)
#      weather_date  weather_tavg  weather_tmin  weather_tmax  weather_prcp  \
# 0      2010-01-01         -31.6         -37.2         -19.9           NaN
# 1      2010-01-02         -18.4         -20.0         -13.8           NaN
# 2      2010-01-03         -14.3         -22.0         -13.0           NaN
# 3      2010-01-04         -16.2         -22.3         -12.0           NaN
# 4      2010-01-05         -12.5         -14.4         -11.8           NaN
# ...           ...           ...           ...           ...           ...
# 9859   2018-12-28          -5.6         -13.0           1.8           0.0
# 9860   2018-12-29           2.6          -3.9           9.1           0.0
# 9861   2018-12-30          -4.9         -13.7           4.0           0.9
# 9862   2018-12-31         -11.4         -14.7          -8.0           0.0
# 9863   2019-01-01          -2.9         -11.6           5.9           0.0
#
#       weather_snow  weather_wdir  weather_wspd  weather_wpgt  weather_pres  \
# 0              NaN         141.0          22.7           NaN        1037.5
# 1              NaN         140.0          38.1           NaN        1022.8
# 2              NaN           1.0          13.6           NaN        1034.2
# 3              NaN         132.0           9.7           NaN        1035.1
# 4              NaN           NaN          10.8           NaN        1030.6
# ...            ...           ...           ...           ...           ...
# 9859          40.0         240.0          12.4         194.4        1019.1
# 9860          40.0         240.0          13.6         151.2        1002.2
# 9861          40.0           3.0          25.3         241.2        1016.5
# 9862          40.0         197.0          11.2           NaN        1031.8
# 9863          40.0         261.0          13.8          50.0        1014.6
#
#      weather_tsun station
# 0            None   71863
# 1            None   71863
# 2            None   71863
# 3            None   71863
# 4            None   71863
# ...           ...     ...
# 9859         None   71877
# 9860         None   71877
# 9861         None   71877
# 9862         None   71877
# 9863         None   71877
#
# [9864 rows x 12 columns]

# %%
# Download weather data from different stations in the countries Brasil, France and Canada
# France

url = "https://meteostat.p.rapidapi.com/stations/daily"

# Set stations
stations = ["07510",
            "07059",
            "07643"
            ]

# Set API key (defined already)
headers = {
	"X-RapidAPI-Key": "38c2ec0004msh8992e15e6b32155p15fd43jsn0376b99a111e",
	"X-RapidAPI-Host": "meteostat.p.rapidapi.com"
}

# Create empty dataframe, will be used to append each location's weather data
weather_df = pd.DataFrame([])



# Loop through all locations
for station in stations:
    # API call start for open weather
    querystring = {"station":station,"start":"2010-01-01","end":"2019-01-01"}

    response = requests.get(url, headers=headers, params=querystring)
    #API call end

    # time.sleep(1) #uncomment if you run into a query limit
    
    # Decode repsonse with json decoder
    weather_temp = response.json()
    
    # Flatten json response
    weather_temp_df = pd.json_normalize(weather_temp, 
                                        sep="_", 
                                        record_path="data",
                                        meta=["station"], 
                                        record_prefix="weather_",
                                        errors='ignore'
                                        )
    weather_temp_df['station']=station
    # concatenate dataframes
    weather_df = pd.concat([weather_df, weather_temp_df], ignore_index=True)

# Print final dataset weather_df
weather_df_fran=weather_df
weather_df_fran
# Out:
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_5366/1115059080.py:46: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   weather_df = pd.concat([weather_df, weather_temp_df], ignore_index=True)
#      weather_date  weather_tavg  weather_tmin  weather_tmax  weather_prcp  \
# 0      2010-01-01           6.1           2.9           7.6           2.0
# 1      2010-01-02           3.4           1.3           5.8           0.0
# 2      2010-01-03           3.5           1.9           4.6           4.8
# 3      2010-01-04           3.4           3.0           4.0           0.0
# 4      2010-01-05          -1.3          -1.9          -0.7           0.0
# ...           ...           ...           ...           ...           ...
# 9859   2018-12-28           5.6          -0.1          11.4           0.0
# 9860   2018-12-29           4.7          -2.0          11.7           0.0
# 9861   2018-12-30           7.8          -1.4          17.4           0.0
# 9862   2018-12-31           6.2           0.5          15.0           0.0
# 9863   2019-01-01           8.3           2.8          14.3           0.0
#
#       weather_snow  weather_wdir  weather_wspd  weather_wpgt  weather_pres  \
# 0              NaN         271.0          20.7           NaN        1001.6
# 1              NaN          64.0          11.2           NaN        1019.3
# 2              NaN          92.0          20.2           NaN        1014.5
# 3              NaN           4.0          12.5           NaN        1010.6
# 4              NaN         332.0          11.6           NaN        1006.1
# ...            ...           ...           ...           ...           ...
# 9859           NaN         348.0           5.1          27.8        1027.5
# 9860           NaN         350.0           7.2          20.4        1029.7
# 9861           NaN         342.0          14.7          44.0        1028.9
# 9862           NaN         336.0           5.4          25.9        1029.0
# 9863           NaN         350.0          12.6          33.0        1029.2
#
#      weather_tsun station
# 0            None   07510
# 1            None   07510
# 2            None   07510
# 3            None   07510
# 4            None   07510
# ...           ...     ...
# 9859         None   07643
# 9860         None   07643
# 9861         None   07643
# 9862         None   07643
# 9863         None   07643
#
# [9864 rows x 12 columns]

# %% [markdown]
# ## EDA weather data - temperature

# %%
# mean temperature along the years
# three diagrams per country --> nine diagrams
# starting with brazil

plt.style.use('ggplot')

# for station 83362, Cuiaba 
weather_df_cuiaba=weather_df_brazil[weather_df_brazil['station']=='83362']
weather_df_cuiaba

# monatlich mitteln

plt.plot(weather_df_cuiaba['weather_date'],weather_df_cuiaba['weather_tavg'])

# %%
#defining a new dataframe that contains the average temperature of all weather stations

#dropping columns
tavg_df_brazil=weather_df_brazil.drop(['weather_tmin','weather_tmax','weather_prcp','weather_snow','weather_wdir','weather_wspd','weather_wpgt','weather_pres','weather_tsun'], axis='columns')

tavg_df_can=weather_df_can.drop(['weather_tmin','weather_tmax','weather_prcp','weather_snow','weather_wdir','weather_wspd','weather_wpgt','weather_pres','weather_tsun'], axis='columns')

tavg_df_fran=weather_df_fran.drop(['weather_tmin','weather_tmax','weather_prcp','weather_snow','weather_wdir','weather_wspd','weather_wpgt','weather_pres','weather_tsun'], axis='columns')

#defining a large dataframe

tavg_df=pd.concat([tavg_df_brazil,tavg_df_can,tavg_df_fran])

#creating an empty data frame including only the weather_date

tavg_df_cuiaba=tavg_df_brazil[tavg_df_brazil['station']=='83362']
tavg_df_all=tavg_df_cuiaba.drop(['station'], axis='columns')
tavg_df_all

#filtering for the weather stations

stations=['83362','82191','83967','71863','71508','71877','07510','07059','07643']

for station in stations:
       tavg_df_temp=tavg_df[tavg_df['station']==station]
       tavg_df_all=pd.merge(tavg_df_all,tavg_df_temp, on='weather_date', suffixes=('', f'_{station}'))

tavg_df_all





#defining a dataframe per weather station each



# tavg_df=tavg_df_brazil[tavg_df_brazil['station']=='83362']
# tavg_df=tavg_df.drop('station', axis='columns')

# tavg_df.columns=['weather_date','cuiaba']

# # adding the temperature data of the other weather stations in Brazil
# tavg_df_belem=tavg_df_brazil[tavg_df_brazil['station']== '82191']
# tavg_df=pd.merge(tavg_df,tavg_df_belem,on='weather_date')
# tavg_df=tavg_df.drop('station', axis='columns')
# tavg_df.columns=['weather_date','cuiaba','belem']

# tavg_df_porto=tavg_df_brazil[tavg_df_brazil['station']== '83967']
# tavg_df=pd.merge(tavg_df,tavg_df_porto,on='weather_date')
# tavg_df=tavg_df.drop('station', axis='columns')
# tavg_df.columns=['weather_date','cuiaba','belem','porto_alegre']

# # adding the temperature data of Canada
# tavg_df_regina=tavg_df_can[tavg_df_can['station']== '71863']
# tavg_df=pd.merge(tavg_df,tavg_df_regina,on='weather_date')
# tavg_df=tavg_df.drop('station', axis='columns')
# tavg_df.columns=['weather_date','cuiaba','belem','porto_alegre','regina']

# tavg_df_tor=tavg_df_can[tavg_df_can['station']== '71508']
# tavg_df=pd.merge(tavg_df,tavg_df_tor,on='weather_date')
# tavg_df=tavg_df.drop('station', axis='columns')
# tavg_df.columns=['weather_date','cuiaba','belem','porto_alegre','regina','toronto']

# tavg_df_cal=tavg_df_can[tavg_df_can['station']== '71877']
# tavg_df=pd.merge(tavg_df,tavg_df_cal,on='weather_date')
# tavg_df=tavg_df.drop('station', axis='columns')
# tavg_df.columns=['weather_date','cuiaba','belem','porto_alegre','regina','toronto','calgary']
# Out:
#      weather_date  weather_tavg  weather_tavg_83362 station  \
# 0      2010-01-01          26.4                26.4   83362
# 1      2010-01-02          24.3                24.3   83362
# 2      2010-01-03          26.8                26.8   83362
# 3      2010-01-04          29.2                29.2   83362
# 4      2010-01-05          30.2                30.2   83362
# ...           ...           ...                 ...     ...
# 3283   2018-12-28          25.6                25.6   83362
# 3284   2018-12-29          25.0                25.0   83362
# 3285   2018-12-30          25.4                25.4   83362
# 3286   2018-12-31          23.8                23.8   83362
# 3287   2019-01-01          24.6                24.6   83362
#
#       weather_tavg_82191 station_82191  weather_tavg_83967 station_83967  \
# 0                    NaN         82191                26.2         83967
# 1                    NaN         82191                26.9         83967
# 2                    NaN         82191                27.7         83967
# 3                    NaN         82191                24.7         83967
# 4                    NaN         82191                27.8         83967
# ...                  ...           ...                 ...           ...
# 3283                26.5         82191                28.9         83967
# 3284                25.9         82191                28.3         83967
# 3285                25.9         82191                29.1         83967
# 3286                25.4         82191                27.9         83967
# 3287                26.0         82191                29.8         83967
#
#       weather_tavg_71863 station_71863  weather_tavg_71508 station_71508  \
# 0                  -31.6         71863                -4.0         71508
# 1                  -18.4         71863               -13.1         71508
# 2                  -14.3         71863               -12.0         71508
# 3                  -16.2         71863                -9.4         71508
# 4                  -12.5         71863                -7.0         71508
# ...                  ...           ...                 ...           ...
# 3283               -21.8         71863                 7.5         71508
# 3284                -8.8         71863                -0.8         71508
# 3285                -9.2         71863                -1.7         71508
# 3286               -22.3         71863                 2.7         71508
# 3287               -21.9         71863                -0.1         71508
#
#       weather_tavg_71877 station_71877  weather_tavg_07510 station_07510  \
# 0                  -17.5         71877                 6.1         07510
# 1                  -13.0         71877                 3.4         07510
# 2                  -10.8         71877                 3.5         07510
# 3                  -10.9         71877                 3.4         07510
# 4                  -14.1         71877                -1.3         07510
# ...                  ...           ...                 ...           ...
# 3283                -5.6         71877                 9.9         07510
# 3284                 2.6         71877                 0.8         07510
# 3285                -4.9         71877                 2.7         07510
# 3286               -11.4         71877                 3.6         07510
# 3287                -2.9         71877                 6.3         07510
#
#       weather_tavg_07059 station_07059  weather_tavg_07643 station_07643
# 0                    NaN         07059                 9.4         07643
# 1                    NaN         07059                 3.4         07643
# 2                    NaN         07059                 1.6         07643
# 3                    NaN         07059                 3.8         07643
# 4                    NaN         07059                 5.1         07643
# ...                  ...           ...                 ...           ...
# 3283                -0.4         07059                 5.6         07643
# 3284                 NaN         07059                 4.7         07643
# 3285                 6.9         07059                 7.8         07643
# 3286                 8.0         07059                 6.2         07643
# 3287                 7.2         07059                 8.3         07643
#
# [3288 rows x 20 columns]
