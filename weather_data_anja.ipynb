# %% [markdown]
# ## Download weather data via API

# %%
# Import the necessary package
import pandas as pd
import numpy as np
import requests 
import json
from matplotlib import pyplot as plt

# %%
#pip install meteostat

# %%
# defining the weather station codes via meteostat

# %%
# Download weather data from different stations in the countries Brasil, France and Canada
# Starting with Brasil

url = "https://meteostat.p.rapidapi.com/stations/daily"

# Set stations
stations = ["83362",
            "82191",
            "83967"
            ]

# Set API key (defined already)
headers = {
	"X-RapidAPI-Key": "38c2ec0004msh8992e15e6b32155p15fd43jsn0376b99a111e",
	"X-RapidAPI-Host": "meteostat.p.rapidapi.com"
}

# Create empty dataframe, will be used to append each location's weather data
weather_df = pd.DataFrame([])



# Loop through all locations
for station in stations:
    # API call start for open weather
    querystring = {"station":station,"start":"2010-01-01","end":"2019-01-01"}

    response = requests.get(url, headers=headers, params=querystring)
    #API call end

    # time.sleep(1) #uncomment if you run into a query limit
    
    # Decode repsonse with json decoder
    weather_temp = response.json()
    
    # Flatten json response
    weather_temp_df = pd.json_normalize(weather_temp, 
                                        sep="_", 
                                        record_path="data",
                                        meta=["station"], 
                                        record_prefix="weather_",
                                        errors='ignore'
                                        )
    weather_temp_df['station']=station
    # concatenate dataframes
    weather_df = pd.concat([weather_df, weather_temp_df], ignore_index=True)

# Print final dataset weather_df
weather_df_brazil=weather_df
weather_df_brazil
# Out:
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_9739/3211821515.py:46: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   weather_df = pd.concat([weather_df, weather_temp_df], ignore_index=True)
#      weather_date  weather_tavg  weather_tmin  weather_tmax weather_prcp  \
# 0      2010-01-01          26.4          22.4          32.0         None
# 1      2010-01-02          24.3          23.8          26.0         None
# 2      2010-01-03          26.8          24.0          32.0         None
# 3      2010-01-04          29.2          23.0          35.0         None
# 4      2010-01-05          30.2          26.0          35.5         None
# ...           ...           ...           ...           ...          ...
# ...

# %%
# Download weather data from different stations in the countries Brasil, France and Canada
# Canada

url = "https://meteostat.p.rapidapi.com/stations/daily"

# Set stations
stations = ["71863",
            "71508",
            "71877"
            ]

# Set API key (defined already)
headers = {
	"X-RapidAPI-Key": "38c2ec0004msh8992e15e6b32155p15fd43jsn0376b99a111e",
	"X-RapidAPI-Host": "meteostat.p.rapidapi.com"
}

# Create empty dataframe, will be used to append each location's weather data
weather_df = pd.DataFrame([])



# Loop through all locations
for station in stations:
    # API call start for open weather
    querystring = {"station":station,"start":"2010-01-01","end":"2019-01-01"}

    response = requests.get(url, headers=headers, params=querystring)
    #API call end

    # time.sleep(1) #uncomment if you run into a query limit
    
    # Decode repsonse with json decoder
    weather_temp = response.json()
    
    # Flatten json response
    weather_temp_df = pd.json_normalize(weather_temp, 
                                        sep="_", 
                                        record_path="data",
                                        meta=["station"], 
                                        record_prefix="weather_",
                                        errors='ignore'
                                        )
    weather_temp_df['station']=station
    # concatenate dataframes
    weather_df = pd.concat([weather_df, weather_temp_df], ignore_index=True)

# Print final dataset weather_df
weather_df_can=weather_df
weather_df_can
# Out:
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_9739/1924104632.py:46: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   weather_df = pd.concat([weather_df, weather_temp_df], ignore_index=True)
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_9739/1924104632.py:46: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   weather_df = pd.concat([weather_df, weather_temp_df], ignore_index=True)
#      weather_date  weather_tavg  weather_tmin  weather_tmax  weather_prcp  \
# ...

# %%
# Download weather data from different stations in the countries Brasil, France and Canada
# France

url = "https://meteostat.p.rapidapi.com/stations/daily"

# Set stations
stations = ["07510",
            "07059",
            "07643"
            ]

# Set API key (defined already)
headers = {
	"X-RapidAPI-Key": "38c2ec0004msh8992e15e6b32155p15fd43jsn0376b99a111e",
	"X-RapidAPI-Host": "meteostat.p.rapidapi.com"
}

# Create empty dataframe, will be used to append each location's weather data
weather_df = pd.DataFrame([])



# Loop through all locations
for station in stations:
    # API call start for open weather
    querystring = {"station":station,"start":"2010-01-01","end":"2019-01-01"}

    response = requests.get(url, headers=headers, params=querystring)
    #API call end

    # time.sleep(1) #uncomment if you run into a query limit
    
    # Decode repsonse with json decoder
    weather_temp = response.json()
    
    # Flatten json response
    weather_temp_df = pd.json_normalize(weather_temp, 
                                        sep="_", 
                                        record_path="data",
                                        meta=["station"], 
                                        record_prefix="weather_",
                                        errors='ignore'
                                        )
    weather_temp_df['station']=station
    # concatenate dataframes
    weather_df = pd.concat([weather_df, weather_temp_df], ignore_index=True)

# Print final dataset weather_df
weather_df_fran=weather_df
weather_df_fran
# Out:
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_9739/1115059080.py:46: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   weather_df = pd.concat([weather_df, weather_temp_df], ignore_index=True)
#      weather_date  weather_tavg  weather_tmin  weather_tmax  weather_prcp  \
# 0      2010-01-01           6.1           2.9           7.6           2.0
# 1      2010-01-02           3.4           1.3           5.8           0.0
# 2      2010-01-03           3.5           1.9           4.6           4.8
# 3      2010-01-04           3.4           3.0           4.0           0.0
# 4      2010-01-05          -1.3          -1.9          -0.7           0.0
# ...           ...           ...           ...           ...           ...
# ...

# %% [markdown]
# ## EDA weather data - temperature

# %%
#defining a new dataframe that contains the average temperature of all weather stations

#dropping columns
tavg_df_brazil=weather_df_brazil.drop(['weather_tmin','weather_tmax','weather_prcp','weather_snow','weather_wdir','weather_wspd','weather_wpgt','weather_pres','weather_tsun'], axis='columns')

tavg_df_can=weather_df_can.drop(['weather_tmin','weather_tmax','weather_prcp','weather_snow','weather_wdir','weather_wspd','weather_wpgt','weather_pres','weather_tsun'], axis='columns')

tavg_df_fran=weather_df_fran.drop(['weather_tmin','weather_tmax','weather_prcp','weather_snow','weather_wdir','weather_wspd','weather_wpgt','weather_pres','weather_tsun'], axis='columns')

#defining a large dataframe

tavg_df=pd.concat([tavg_df_brazil,tavg_df_can,tavg_df_fran])

#creating an empty data frame including the weather_date to add the data of the other stations later

tavg_df_cuiaba=tavg_df_brazil[tavg_df_brazil['station']=='83362']
tavg_df_all=tavg_df_cuiaba.drop(['station'], axis='columns')
tavg_df_all

#filtering the complete data set for the weather stations
#adding the temperature data to the new dataset to have the temperature for each station in a column

stations=['83362','82191','83967','71863','71508','71877','07510','07059','07643']

for station in stations:
       tavg_df_temp=tavg_df[tavg_df['station']==station]
       tavg_df_all=pd.merge(tavg_df_all,tavg_df_temp, on='weather_date', suffixes=('', f'_{station}'))
       tavg_df_all=tavg_df_all.drop('station', axis='columns')

tavg_df_all=tavg_df_all.drop('weather_tavg', axis='columns')
tavg_df_all=tavg_df_all.reset_index()
tavg_df_all
# Out:
#       index weather_date  weather_tavg_83362  weather_tavg_82191  \
# 0         0   2010-01-01                26.4                 NaN
# 1         1   2010-01-02                24.3                 NaN
# 2         2   2010-01-03                26.8                 NaN
# 3         3   2010-01-04                29.2                 NaN
# 4         4   2010-01-05                30.2                 NaN
# ...     ...          ...                 ...                 ...
# 3283   3283   2018-12-28                25.6                26.5
# 3284   3284   2018-12-29                25.0                25.9
# 3285   3285   2018-12-30                25.4                25.9
# 3286   3286   2018-12-31                23.8                25.4
# 3287   3287   2019-01-01                24.6                26.0
#
#       weather_tavg_83967  weather_tavg_71863  weather_tavg_71508  \
# 0                   26.2               -31.6                -4.0
# ...

# %%
# defining a dataframe that shows the monthly temperature to have a smooth curve
# using groupby

tavg_df_all['weather_date'] = pd.to_datetime(tavg_df_all['weather_date'])

tavg_df_month=tavg_df_all.groupby(tavg_df_all['weather_date'].dt.to_period("M")).mean().round()

#through this operation, two indexes are built (weather_date)
#rename one of it 

tavg_df_month=tavg_df_month.rename(columns={'weather_date':'weather_date_day'})

#reset the index
tavg_df_month=tavg_df_month.reset_index()

#drop one of the weather date columns

tavg_df_month=tavg_df_month.drop('weather_date_day', axis='columns')

#renaming the columns by using a dictionary

city_station={
    '83362':'cuiaba',
    '82191':'belem',
    '83967':'porto_alegre',
    '71863':'regina',
    '71508':'toronto',
    '71877':'calgary',
    '07510':'bordeaux',
    '07059':'amiens',
    '07643':'montpellier'
}

# dropping the 'weather_tavg_' from the column name

tavg_df_month.columns=tavg_df_month.columns.str.replace('weather_tavg_','')

tavg_df_month=tavg_df_month.rename(columns=city_station)
tavg_df_month.sample(5)
# Out:
#    weather_date   index  cuiaba  belem  porto_alegre  regina  toronto  \
# 50      2014-03  1535.0    26.0    NaN          24.0   -10.0     -3.0
# 77      2016-06  2358.0    23.0    NaN          11.0    17.0     20.0
# 54      2014-07  1657.0    23.0    NaN          14.0    19.0     21.0
# 74      2016-03  2266.0    27.0    NaN          23.0    -0.0      3.0
# 27      2012-04   836.0    26.0    NaN          20.0     5.0      8.0
#
#     calgary  bordeaux  amiens  montpellier
# 50     -7.0      10.0     8.0         12.0
# 77     16.0      18.0    16.0         22.0
# 54     19.0      20.0    18.0         24.0
# 74      3.0       9.0     6.0         11.0
# 27      5.0      10.0     8.0         14.0

# %%
tavg_df_month.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   weather_date  109 non-null    period[M]
#  1   index         109 non-null    float64
#  2   cuiaba        109 non-null    float64
#  3   belem         7 non-null      float64
#  4   porto_alegre  109 non-null    float64
#  5   regina        109 non-null    float64
#  6   toronto       109 non-null    float64
#  7   calgary       109 non-null    float64
#  8   bordeaux      109 non-null    float64
#  9   amiens        100 non-null    float64
#  10  montpellier   109 non-null    float64
# dtypes: float64(10), period[M](1)
# memory usage: 9.5 KB

# %%
tavg_df_month.describe().round()
# Out:
#         index  cuiaba  belem  porto_alegre  regina  toronto  calgary  \
# count   109.0   109.0    7.0         109.0   109.0    109.0    109.0
# mean   1657.0    26.0   27.0          21.0     3.0     10.0      5.0
# std     962.0     2.0    1.0           4.0    12.0     10.0      9.0
# min      15.0    23.0   26.0          11.0   -22.0    -11.0    -12.0
# 25%     836.0    25.0   26.0          17.0    -8.0      1.0     -3.0
# 50%    1657.0    27.0   27.0          21.0     5.0     10.0      5.0
# 75%    2480.0    27.0   27.0          24.0    15.0     19.0     14.0
# max    3287.0    30.0   27.0          30.0    21.0     25.0     19.0
#
#        bordeaux  amiens  montpellier
# count     109.0   100.0        109.0
# mean       14.0    11.0         16.0
# std         6.0     5.0          6.0
# min         3.0    -1.0          4.0
# 25%         9.0     6.0         10.0
# 50%        14.0    12.0         15.0
# 75%        19.0    16.0         21.0
# max        24.0    21.0         26.0

# %%
#converting the datatype of the weather date to datetime
tavg_df_month['weather_date']=tavg_df_month['weather_date'].astype('datetime64')

# %%
#plotting the nine graphs in one collage

fig, axes = plt.subplots(3, 3, figsize=(20, 20))


axes[0][0].plot(tavg_df_month['weather_date'], tavg_df_month['cuiaba'])
axes[0][0].set_xticklabels(tavg_df_month['weather_date'].astype(str)[::4], rotation=60)
axes[0][0].set_title('Cuiaba')
axes[0][0].set_ylim(-10,35)
axes[0][0].set_ylabel('monthly mean temperature in °C')

axes[0][1].plot(tavg_df_month['weather_date'], tavg_df_month['belem'])
axes[0][1].set_xticklabels(tavg_df_month['weather_date'].astype(str)[::4], rotation=60)
axes[0][1].set_title('Belém')
axes[0][1].set_ylim(-10,35)
axes[0][1].set_ylabel('monthly mean temperature in °C')

axes[0][2].plot(tavg_df_month['weather_date'], tavg_df_month['porto_alegre'])
axes[0][2].set_xticklabels(tavg_df_month['weather_date'].astype(str)[::4], rotation=60)
axes[0][2].set_title('Porto Alegre')
axes[0][2].set_ylim(-10,35)
axes[0][2].set_ylabel('monthly mean temperature in °C')

axes[1][0].plot(tavg_df_month['weather_date'], tavg_df_month['regina'])
axes[1][0].set_xticklabels(tavg_df_month['weather_date'].astype(str)[::4], rotation=60)
axes[1][0].set_title('Regina')
axes[1][0].set_ylim(-10,35)
axes[1][0].set_ylabel('monthly mean temperature in °C')

axes[1][1].plot(tavg_df_month['weather_date'], tavg_df_month['toronto'])
axes[1][1].set_xticklabels(tavg_df_month['weather_date'].astype(str)[::4], rotation=60)
axes[1][1].set_title('Toronto')
axes[1][1].set_ylim(-10,35)
axes[1][1].set_ylabel('monthly mean temperature in °C')

axes[1][2].plot(tavg_df_month['weather_date'], tavg_df_month['calgary'])
axes[1][2].set_xticklabels(tavg_df_month['weather_date'].astype(str)[::4], rotation=60)
axes[1][2].set_title('Calgary')
axes[1][2].set_ylim(-10,35)
axes[1][2].set_ylabel('monthly mean temperature in °C')

axes[2][0].plot(tavg_df_month['weather_date'], tavg_df_month['bordeaux'])
axes[2][0].set_xticklabels(tavg_df_month['weather_date'].astype(str)[::4], rotation=60)
axes[2][0].set_title('Bordeaux')
axes[2][0].set_ylim(-10,35)
axes[2][0].set_ylabel('monthly mean temperature in °C')

axes[2][1].plot(tavg_df_month['weather_date'], tavg_df_month['amiens'])
axes[2][1].set_xticklabels(tavg_df_month['weather_date'].astype(str)[::4], rotation=60)
axes[2][1].set_title('Amiens')
axes[2][1].set_ylim(-10,35)
axes[2][1].set_ylabel('monthly mean temperature in °C')

axes[2][2].plot(tavg_df_month['weather_date'], tavg_df_month['montpellier'])
axes[2][2].set_xticklabels(tavg_df_month['weather_date'].astype(str)[::4], rotation=60)
axes[2][2].set_title('Montpellier')
axes[2][2].set_ylim(-10,35)
axes[2][2].set_ylabel('monthly mean temperature in °C')
# Out:
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_9739/292100262.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0][0].set_xticklabels(tavg_df_month['weather_date'].astype(str)[::4], rotation=60)
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_9739/292100262.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0][1].set_xticklabels(tavg_df_month['weather_date'].astype(str)[::4], rotation=60)
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_9739/292100262.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0][2].set_xticklabels(tavg_df_month['weather_date'].astype(str)[::4], rotation=60)
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_9739/292100262.py:25: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1][0].set_xticklabels(tavg_df_month['weather_date'].astype(str)[::4], rotation=60)
# ...

# %%
# plot as for-loop

fig, axes = plt.subplots(3, 3, figsize=(20, 20))

#cities as a list  
cities=tavg_df_month.columns.tolist()
cities.remove('weather_date')
cities.remove('index')

#creating the plots
#indexes for the positions of the graphs

i=0
j=0
n=0
m=0

for city in cities:

    axes[i][j].plot(tavg_df_month['weather_date'], tavg_df_month[city])
    axes[i][j].set_xticklabels(tavg_df_month['weather_date'].astype(str)[::12], rotation=60)
    axes[i][j].set_title(city)
    axes[i][j].set_ylim(-10,35)
    axes[i][j].set_ylabel('monthly mean temperature in °C')

    n=n+0.34
    i=int(n)
    
    m=m+1
    j=m%3
# Out:
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_9739/2875550892.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[i][j].set_xticklabels(tavg_df_month['weather_date'].astype(str)[::12], rotation=60)
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_9739/2875550892.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[i][j].set_xticklabels(tavg_df_month['weather_date'].astype(str)[::12], rotation=60)
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_9739/2875550892.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[i][j].set_xticklabels(tavg_df_month['weather_date'].astype(str)[::12], rotation=60)
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_9739/2875550892.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...

# %% [markdown]
# ## EDA weather data - precipitation

# %%
#defining a new dataframe that contains the average temperature of all weather stations

#dropping columns
prec_df_brazil=weather_df_brazil.drop(['weather_tavg','weather_tmin','weather_tmax','weather_snow','weather_wdir','weather_wspd','weather_wpgt','weather_pres','weather_tsun'], axis='columns')

prec_df_can=weather_df_can.drop(['weather_tavg','weather_tmin','weather_tmax','weather_snow','weather_wdir','weather_wspd','weather_wpgt','weather_pres','weather_tsun'], axis='columns')

prec_df_fran=weather_df_fran.drop(['weather_tavg','weather_tmin','weather_tmax','weather_snow','weather_wdir','weather_wspd','weather_wpgt','weather_pres','weather_tsun'], axis='columns')

#defining a large dataframe

prec_df=pd.concat([prec_df_brazil,prec_df_can,prec_df_fran])
prec_df
# Out:
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_9739/3008643672.py:12: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   prec_df=pd.concat([prec_df_brazil,prec_df_can,prec_df_fran])
#      weather_date  weather_prcp station
# 0      2010-01-01           NaN   83362
# 1      2010-01-02           NaN   83362
# 2      2010-01-03           NaN   83362
# 3      2010-01-04           NaN   83362
# 4      2010-01-05           NaN   83362
# ...           ...           ...     ...
# 9859   2018-12-28           0.0   07643
# 9860   2018-12-29           0.0   07643
# 9861   2018-12-30           0.0   07643
# 9862   2018-12-31           0.0   07643
# 9863   2019-01-01           0.0   07643
#
# [29592 rows x 3 columns]

# %%
#creating an empty data frame including the weather_date to add the data of the other stations later

prec_df_cuiaba=prec_df_brazil[prec_df_brazil['station']=='83362']
prec_df_all=prec_df_cuiaba.drop(['station'], axis='columns')
prec_df_all

#filtering the complete data set for the weather stations
#adding the temperature data to the new dataset to have the temperature for each station in a column

stations=['83362','82191','83967','71863','71508','71877','07510','07059','07643']

for station in stations:
       prec_df_temp=prec_df[prec_df['station']==station]
       prec_df_all=pd.merge(prec_df_all,prec_df_temp, on='weather_date', suffixes=('', f'_{station}'))
       prec_df_all=prec_df_all.drop('station', axis='columns')

prec_df_all=prec_df_all.drop('weather_prcp', axis='columns')
prec_df_all=prec_df_all.reset_index()
prec_df_all
# Out:
#       index weather_date  weather_prcp_83362  weather_prcp_82191  \
# 0         0   2010-01-01                 NaN                 NaN
# 1         1   2010-01-02                 NaN                 NaN
# 2         2   2010-01-03                 NaN                 NaN
# 3         3   2010-01-04                 NaN                 NaN
# 4         4   2010-01-05                 NaN                 NaN
# ...     ...          ...                 ...                 ...
# 3283   3283   2018-12-28                 NaN                 NaN
# 3284   3284   2018-12-29                 NaN                 NaN
# 3285   3285   2018-12-30                 NaN                 NaN
# 3286   3286   2018-12-31                 NaN                 NaN
# 3287   3287   2019-01-01                 NaN                 NaN
#
#       weather_prcp_83967  weather_prcp_71863  weather_prcp_71508  \
# 0                    NaN                 NaN                 1.3
# ...

# %%
# defining a dataframe that shows the monthly precipitation to have a smooth curve
# using groupby

prec_df_all['weather_date'] = pd.to_datetime(prec_df_all['weather_date'])

prec_df_month=prec_df_all.groupby(prec_df_all['weather_date'].dt.to_period("M")).mean().round()

#through this operation, two indexes are built (weather_date)
#rename one of it 

prec_df_month=prec_df_month.rename(columns={'weather_date':'weather_date_day'})

#reset the index
prec_df_month=prec_df_month.reset_index()

#drop one of the weather date columns

prec_df_month=prec_df_month.drop('weather_date_day', axis='columns')

#renaming the columns by using a dictionary

city_station={
    '83362':'cuiaba',
    '82191':'belem',
    '83967':'porto_alegre',
    '71863':'regina',
    '71508':'toronto',
    '71877':'calgary',
    '07510':'bordeaux',
    '07059':'amiens',
    '07643':'montpellier'
}

# dropping the 'weather_prcp_' from the column name

prec_df_month.columns=prec_df_month.columns.str.replace('weather_prcp_','')

prec_df_month=prec_df_month.rename(columns=city_station)
prec_df_month.sample(5)
# Out:
#    weather_date   index  cuiaba  belem  porto_alegre  regina  toronto  \
# 51      2014-04  1566.0     NaN    NaN           NaN     NaN      4.0
# 41      2013-06  1262.0     NaN    NaN           NaN     NaN      4.0
# 48      2014-01  1476.0     NaN    NaN           NaN     NaN      1.0
# 91      2017-08  2784.0     NaN    NaN           NaN     NaN      1.0
# 55      2014-08  1688.0     NaN    NaN           NaN     NaN      0.0
#
#     calgary  bordeaux  amiens  montpellier
# 51      1.0       3.0     NaN          1.0
# 41      5.0       4.0     NaN          1.0
# 48      0.0       6.0     NaN          2.0
# 91      1.0       1.0     NaN          0.0
# 55      2.0       3.0     NaN          1.0

# %%
prec_df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3288 entries, 0 to 3287
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               3288 non-null   int64
#  1   weather_date        3288 non-null   datetime64[ns]
#  2   weather_prcp_83362  0 non-null      float64
#  3   weather_prcp_82191  0 non-null      float64
#  4   weather_prcp_83967  0 non-null      float64
#  5   weather_prcp_71863  0 non-null      float64
#  6   weather_prcp_71508  3166 non-null   float64
#  7   weather_prcp_71877  2267 non-null   float64
#  8   weather_prcp_07510  3288 non-null   float64
#  9   weather_prcp_07059  0 non-null      float64
#  10  weather_prcp_07643  3241 non-null   float64
# dtypes: datetime64[ns](1), float64(9), int64(1)
# memory usage: 282.7 KB

# %%
prec_df_month.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   weather_date  109 non-null    period[M]
#  1   index         109 non-null    float64
#  2   cuiaba        0 non-null      float64
#  3   belem         0 non-null      float64
#  4   porto_alegre  0 non-null      float64
#  5   regina        0 non-null      float64
#  6   toronto       109 non-null    float64
#  7   calgary       79 non-null     float64
#  8   bordeaux      109 non-null    float64
#  9   amiens        0 non-null      float64
#  10  montpellier   109 non-null    float64
# dtypes: float64(10), period[M](1)
# memory usage: 9.5 KB

# %%
prec_df_all.describe().round()
# Out:
#         index         weather_date  weather_prcp_83362  weather_prcp_82191  \
# count  3288.0                 3288                 0.0                 0.0
# mean   1644.0  2014-07-02 12:00:00                 NaN                 NaN
# min       0.0  2010-01-01 00:00:00                 NaN                 NaN
# 25%     822.0  2012-04-01 18:00:00                 NaN                 NaN
# 50%    1644.0  2014-07-02 12:00:00                 NaN                 NaN
# 75%    2465.0  2016-10-01 06:00:00                 NaN                 NaN
# max    3287.0  2019-01-01 00:00:00                 NaN                 NaN
# std     949.0                  NaN                 NaN                 NaN
#
#        weather_prcp_83967  weather_prcp_71863  weather_prcp_71508  \
# count                 0.0                 0.0              3166.0
# mean                  NaN                 NaN                 2.0
# min                   NaN                 NaN                 0.0
# ...

# %%
#converting the datatype of the weather date to datetime
#prec_df_month['weather_date']=prec_df_month['weather_date'].astype('datetime64')

city_station={
    '83362':'cuiaba',
    '82191':'belem',
    '83967':'porto_alegre',
    '71863':'regina',
    '71508':'toronto',
    '71877':'calgary',
    '07510':'bordeaux',
    '07059':'amiens',
    '07643':'montpellier'
}

# dropping the 'weather_prcp_' from the column name

prec_df_all.columns=prec_df_all.columns.str.replace('weather_prcp_','')

prec_df_all=prec_df_all.rename(columns=city_station)
prec_df_all.sample(5)


# plot as for-loop

fig, axes = plt.subplots(3, 3, figsize=(20, 20))

#cities as a list  
cities=prec_df_all.columns.tolist()
cities.remove('weather_date')
cities.remove('index')

#creating the plots
#indexes for the positions of the graphs

i=0
j=0
n=0
m=0

for city in cities:

    axes[i][j].bar(prec_df_all['weather_date'], prec_df_all[city])
    axes[i][j].set_xticklabels(prec_df_all['weather_date'].astype(str)[::300], rotation=60)
    axes[i][j].set_title(city)
    axes[i][j].set_ylim(0,50)
    axes[i][j].set_ylabel('precipitation per day')

    n=n+0.34
    i=int(n)
    
    m=m+1
    j=m%3
# Out:
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_9739/2571413847.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[i][j].set_xticklabels(prec_df_all['weather_date'].astype(str)[::300], rotation=60)
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_9739/2571413847.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[i][j].set_xticklabels(prec_df_all['weather_date'].astype(str)[::300], rotation=60)
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_9739/2571413847.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[i][j].set_xticklabels(prec_df_all['weather_date'].astype(str)[::300], rotation=60)
# /var/folders/lh/21dq4gns0xdg8dtbs3c1sgnw0000gn/T/ipykernel_9739/2571413847.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...
